# %%
#Importing Libraries
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import os
import tensorflow as tf

# %%
#Getting directories

style_dir=r'C:\Users\Shirshak\Tensorflow Tutorials\Neural Style Transfer\style'

content_dir=r'C:\Users\Shirshak\Tensorflow Tutorials\Neural Style Transfer\content'

# %%
#Loading the images
style=Image.open(style_dir+'\style1.jpg')
content=Image.open(content_dir+'\content1.jpg')

# %%
#Function to preprocess image
def display(img):
    fig = plt.figure(figsize=(8, 8))
    for j,i in enumerate(img):
        image=np.array(i)
        fig.add_subplot(1,2,j+1)
        plt.imshow(image,interpolation='nearest')
    plt.show()

# %%
display([style,content])

# %%
#Loading the VGG 16 model 
x = tf.keras.applications.vgg16.preprocess_input(content_image*255)
x = tf.image.resize(x, (224, 224))
vgg=tf.keras.applications.vgg16.VGG16(weights='imagenet',include_top=True)
prediction_prob=vgg(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Loading the VGG 16 model
# ----> 2 x = tf.keras.applications.vgg16.preprocess_input(content_image*255)
#       3 x = tf.image.resize(x, (224, 224))
#       4 vgg=tf.keras.applications.vgg16.VGG16(weights='imagenet',include_top=True)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\applications\vgg16.py:229, in preprocess_input(x, data_format)
#     227 @keras_export('keras.applications.vgg16.preprocess_input')
#     228 def preprocess_input(x, data_format=None):
# --> 229   return imagenet_utils.preprocess_input(
#     230       x, data_format=data_format, mode='caffe')
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\applications\imagenet_utils.py:115, in preprocess_input(x, data_format, mode)
#     112   return _preprocess_numpy_input(
#     113       x, data_format=data_format, mode=mode)
#     114 else:
# --> 115   return _preprocess_symbolic_input(
#     116       x, data_format=data_format, mode=mode)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\keras\applications\imagenet_utils.py:276, in _preprocess_symbolic_input(x, data_format, mode)
#     273     x = x[:, ::-1, ...]
#     274 else:
#     275   # 'RGB'->'BGR'
# --> 276   x = x[..., ::-1]
#     277 mean = [103.939, 116.779, 123.68]
#     278 std = None
#
# TypeError: list indices must be integers or slices, not tuple

# %%
content_image=np.array(content)
content_image=[content_image]
# Out:
# C:\Users\Shirshak\AppData\Local\Temp\ipykernel_40412\563860710.py:1: FutureWarning: The input object of type 'JpegImageFile' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'JpegImageFile', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   content_image=np.array([content])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 content_image=np.array([content])
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'JpegImageFile'
